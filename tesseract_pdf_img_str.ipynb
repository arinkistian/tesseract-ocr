# %% [markdown]
# <a href="https://colab.research.google.com/github/arinkistian/tesseract-ocr/blob/main/tesseract_pdf_img_str.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
tests = ["Gambar hasil scan", "Rotasi gambar 10", "Rotasi gambar 30",
         "Rotasi gambar 60", "Rotasi gambar 90", "Rotasi gambar 180",
         "Rotasi gambar 270", "Pengcahayaan rendah dan noise",
         "Gambar foto less noise"]

recall = [0.974843, 0, 0, 0, 0.993827, 0, 0, 0.132530, 0.993827]
precision = [0.974843, 0, 0, 0, 0.987730, 0, 0, 0.666667, 0.987730]
f1 = [0.974843, 0, 0, 0, 0.990769, 0, 0, 0.221106, 0.990769]

# Plotting the data
x = np.arange(len(tests))

plt.plot(x, recall, label='Recall', marker='o')
plt.plot(x, precision, label='Precision', marker='o')
plt.plot(x, f1, label='F1', marker='o')

plt.xlabel('Pengujian')
plt.ylabel('Scores')
plt.title('Recall, Precision, and F1 Scores for PDF File Test')
plt.xticks(x, tests, rotation=45, ha='right')
plt.legend()

plt.tight_layout()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for the second set
tests = ["Gambar hasil scan", "Rotasi gambar 10", "Rotasi gambar 30",
         "Rotasi gambar 60", "Rotasi gambar 90", "Rotasi gambar 180",
         "Rotasi gambar 270", "Pengcahayaan rendah dan noise",
         "Gambar foto less noise"]

recall = [0.974843, 0, 0, 0, 0.888889, 0.888889, 0.888889, 0.204819, 0.889571]
precision = [0.974843, 0, 0, 0, 0.993103, 0.993103, 0.993103, 1.000000, 0.993151]
f1 = [0.974843, 0, 0, 0, 0.938111, 0.938111, 0.938111, 0.340000, 0.938511]

# Plotting the data
x = np.arange(len(tests))

plt.plot(x, recall, label='Recall', marker='o')
plt.plot(x, precision, label='Precision', marker='o')
plt.plot(x, f1, label='F1', marker='o')

plt.xlabel('Pengujian')
plt.ylabel('Scores')
plt.title('Recall, Precision, and F1 Scores for JPG File')
plt.xticks(x, tests, rotation=45, ha='right')
plt.legend()

plt.tight_layout()
plt.grid(True)
plt.show()

# %% [markdown]
# # install dependencies

# %%
# !apt-get install -y poppler-utils
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   poppler-utils
# 0 upgraded, 1 newly installed, 0 to remove and 16 not upgraded.
# Need to get 186 kB of archives.
# After this operation, 696 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 poppler-utils amd64 22.02.0-2ubuntu0.2 [186 kB]
# Fetched 186 kB in 1s (280 kB/s)
# Selecting previously unselected package poppler-utils.
# (Reading database ... 120831 files and directories currently installed.)
# Preparing to unpack .../poppler-utils_22.02.0-2ubuntu0.2_amd64.deb ...
# Unpacking poppler-utils (22.02.0-2ubuntu0.2) ...
# Setting up poppler-utils (22.02.0-2ubuntu0.2) ...
# Processing triggers for man-db (2.10.2-1) ...

# %%
# !sudo apt install tesseract-ocr
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   tesseract-ocr-eng tesseract-ocr-osd
# The following NEW packages will be installed:
#   tesseract-ocr tesseract-ocr-eng tesseract-ocr-osd
# 0 upgraded, 3 newly installed, 0 to remove and 16 not upgraded.
# Need to get 4,816 kB of archives.
# After this operation, 15.6 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr-eng all 1:4.00~git30-7274cfa-1.1 [1,591 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr-osd all 1:4.00~git30-7274cfa-1.1 [2,990 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr amd64 4.1.1-2.1build1 [236 kB]
# Fetched 4,816 kB in 1s (4,323 kB/s)
# debconf: unable to initialize frontend: Dialog
# ...

# %%
pip install pdf2image

# %%
pip install pytesseract

# %%
pip install opencv-python

# %%
# !apt-get install poppler-utils
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# poppler-utils is already the newest version (22.02.0-2ubuntu0.2).
# 0 upgraded, 0 newly installed, 0 to remove and 16 not upgraded.

# %% [markdown]
# # default code

# %%
# @title Default code
# import pdf2image
# from PIL import Image
# import pytesseract
# from google.colab import files

# def pdf_to_img(pdf_file):
#     return pdf2image.convert_from_path(pdf_file)

# def ocr_core(file):
#     text = pytesseract.image_to_string(file)
#     return text

# def extract_text_from_first_page(pdf_file):
#     images = pdf_to_img(pdf_file)
#     first_page_img = images[0]
#     text_first_page = ocr_core(first_page_img)
#     return text_first_page

# def extract_judul(text):
#     start = text.find("Judul Buku")
#     end = text.find("\n", start)
#     judul = text[start:end].replace("Judul Buku", "").strip()
#     return judul

# def extract_isbn(text):
#     start = text.find("ISBN")
#     end = text.find("\n", start)
#     isbn = text[start:end].replace("ISBN", "").strip()
#     return isbn

# def extract_penulis(text):
#     start = text.find("Penulis")
#     end = text.find("\n", start)
#     penulis = text[start:end].replace("Penulis", "").strip()
#     return penulis

# def print_info(pdf_file):
#     # Extract and print information for the first page
#     text_first_page = extract_text_from_first_page(pdf_file)
#     judul = extract_judul(text_first_page)
#     isbn = extract_isbn(text_first_page)
#     penulis = extract_penulis(text_first_page)

#     print("Informasi (Halaman 1):")
#     print("Judul Buku:", judul)
#     print("ISBN:", isbn)
#     print("Penulis:", penulis)

#     # Extract and print information for all pages
#     images = pdf_to_img(pdf_file)
#     all_pages_text = ""
#     for pg, img in enumerate(images):
#         all_pages_text += ocr_core(img)

# def select_pdf_file():
#     uploaded = files.upload()
#     for file_name in uploaded.keys():
#         return file_name

# if __name__ == "__main__":
#     pdf_file = select_pdf_file()
#     if pdf_file:
#         print_info(pdf_file)
#     else:
#         print("No PDF file selected.")

# %%
# @title Full code with improved OCR accuracy for PDF, PNG, and JPEG files

# import pdf2image
# from PIL import Image, ImageEnhance
# import pytesseract
# from google.colab import files

# def pdf_to_img(pdf_file):
#     return pdf2image.convert_from_path(pdf_file)

# def image_to_text(image_file):
#     image = Image.open(image_file)

#     # Pre-process the image to improve OCR accuracy
#     image = image.resize((image.width * 2, image.height * 2))  # Increase image size
#     enhancer = ImageEnhance.Contrast(image)
#     image = enhancer.enhance(1.5)  # Increase contrast

#     return pytesseract.image_to_string(image, lang='eng', config='--psm 6')

# def extract_judul(text):
#     start = text.find("Judul Buku")
#     end = text.find("\n", start)
#     judul = text[start:end].replace("Judul Buku", "").strip()
#     return judul

# def extract_isbn(text):
#     start = text.find("ISBN")
#     end = text.find("\n", start)
#     isbn = text[start:end].replace("ISBN", "").strip()
#     return isbn

# def extract_penulis(text):
#     start = text.find("Penulis")
#     end = text.find("\n", start)
#     penulis = text[start:end].replace("Penulis", "").strip()
#     return penulis

# def print_info(text_data_buku):
#     isbn = extract_isbn(text_data_buku)
#     penulis = extract_penulis(text_data_buku)

#     print("ISBN:", isbn)
#     print("Penulis:", penulis)

# def select_file():
#     uploaded = files.upload()
#     for file_name in uploaded.keys():
#         return file_name

# if __name__ == "__main__":
#     print("Silakan unggah file PDF, PNG, atau JPEG untuk diekstraksi teks.")
#     while True:
#         file_name = select_file()

#         if file_name:
#             if file_name.lower().endswith('.pdf'):
#                 # Process PDF file
#                 print("Proses file:", file_name)
#                 images = pdf_to_img(file_name)
#                 text_data_buku = ""
#                 for pg, img in enumerate(images):
#                     text_data_buku += image_to_text(img)

#                 print_info(text_data_buku)
#             elif file_name.lower().endswith(('.png', '.jpg', '.jpeg')):
#                 # Process image file
#                 print("Proses file:", file_name)
#                 text_data_buku = image_to_text(file_name)

#                 print_info(text_data_buku)
#             else:
#                 print("File yang diunggah harus berformat PDF, PNG, atau JPEG.")
#         else:
#             print("Tidak ada file yang diunggah.")

#         stop_processing = input("Apakah Anda ingin berhenti? (yes/no): ").lower()
#         if stop_processing == "yes":
#             break

# %% [markdown]
# # Pengujian PDF File

# %%
# @title noisy
import pdf2image
from PIL import Image
import pytesseract
from google.colab import files

def pdf_to_img(pdf_file):
    return pdf2image.convert_from_path(pdf_file)

def ocr_core(file):
    text = pytesseract.image_to_string(file)
    return text

def extract_judul(text):
    start = text.find("Judul Buku")
    end = text.find("\n", start)
    judul = text[start:end].replace("Judul Buku", "").strip()
    return judul

def extract_isbn(text):
    start = text.find("ISBN")
    end = text.find("\n", start)
    isbn = text[start:end].replace("ISBN", "").strip()
    return isbn

def extract_penulis(text):
    start = text.find("Penulis")
    end = text.find("\n", start)
    penulis = text[start:end].replace("Penulis", "").strip()
    return penulis

def print_info(pdf_file):
    images = pdf_to_img(pdf_file)
    text_data_buku = ""
    for pg, img in enumerate(images):
        text_data_buku += ocr_core(img)

    isbn = extract_isbn(text_data_buku)
    penulis = extract_penulis(text_data_buku)

    print("ISBN:", isbn)
    print("Penulis:", penulis)

def select_pdf_file():
    uploaded = files.upload()
    for file_name in uploaded.keys():
        return file_name

def collect_ground_truth_data():
    ground_truth_data = {}

    print("Silakan unggah file PDF dengan teks asli. Ketik 'selesai' jika sudah selesai.")
    while True:
        file_name = select_pdf_file()
        if file_name:
            # Proses file PDF yang diunggah
            images = pdf_to_img(file_name)
            text_data_buku = ""
            for pg, img in enumerate(images):
                text_data_buku += ocr_core(img)

            # Simpan teks asli dari PDF ke dalam dictionary berdasarkan nama file
            ground_truth_data[file_name] = text_data_buku

            print("File {} berhasil diunggah dan teks asli telah disimpan.".format(file_name))
        else:
            print("Tidak ada file yang diunggah.")

        stop_collecting = input("Apakah Anda ingin berhenti mengumpulkan data? (yes/no): ").lower()
        if stop_collecting == "yes":
            break

    return ground_truth_data

def calculate_word_error_rate(actual_text, ocr_text):
    actual_words = actual_text.lower().split()
    ocr_words = ocr_text.lower().split()

    total_words = len(actual_words)
    word_errors = sum(1 for word in ocr_words if word not in actual_words)

    if total_words == 0:
        word_error_rate = 0
    else:
        word_error_rate = word_errors / total_words

    return word_error_rate

def calculate_recall_precision(ground_truth_data, ocr_data):
    total_ground_truth_words = 0
    total_correctly_detected_words = 0
    total_detected_words = 0

    for file_name, ground_truth_text in ground_truth_data.items():
        ocr_text = ocr_data.get(file_name, "")

        ground_truth_words = set(ground_truth_text.lower().split())
        ocr_words = set(ocr_text.lower().split())

        correctly_detected_words = ground_truth_words.intersection(ocr_words)
        total_correctly_detected_words += len(correctly_detected_words)

        total_ground_truth_words += len(ground_truth_words)
        total_detected_words += len(ocr_words)

    if total_ground_truth_words == 0:
        # Handle the case when ground_truth_data is empty to avoid division by zero
        recall = 0
    else:
        recall = total_correctly_detected_words / total_ground_truth_words

    if total_detected_words == 0:
        # Handle the case when there are no detected words to avoid division by zero
        precision = 0
    else:
        precision = total_correctly_detected_words / total_detected_words

    return recall, precision


if __name__ == "__main__":
    # Tambahkan kode untuk mengumpulkan data teks asli
    ground_truth_data = collect_ground_truth_data()

    # Proses OCR dan evaluasi menggunakan data teks asli
    ocr_results = {}  # Dictionary to store OCR results for each file
    for pdf_file, actual_text in ground_truth_data.items():
        print("Proses file:", pdf_file)
        images = pdf_to_img(pdf_file)
        text_data_buku = ""
        for pg, img in enumerate(images):
            text_data_buku += ocr_core(img)

        isbn = extract_isbn(text_data_buku)
        penulis = extract_penulis(text_data_buku)

        print("ISBN:", isbn)
        print("Penulis:", penulis)

        # Simpan hasil OCR untuk file ini ke dalam dictionary
        ocr_results[pdf_file] = text_data_buku

    # Hitung dan tampilkan recall dan precision
    recall, precision = calculate_recall_precision(ground_truth_data, ocr_results)
    print("Recall: {:.2f}".format(recall))
    print("Precision: {:.2f}".format(precision))
# Out:
# Silakan unggah file PDF dengan teks asli. Ketik 'selesai' jika sudah selesai.
#      <input type="file" id="files-85afbf41-1c95-4898-bc49-a851076d68de" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-85afbf41-1c95-4898-bc49-a851076d68de">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %%
# @title less noise
import pdf2image
from PIL import Image
import pytesseract
from google.colab import files

def pdf_to_img(pdf_file):
    return pdf2image.convert_from_path(pdf_file)

def ocr_core(file):
    text = pytesseract.image_to_string(file)
    return text

def extract_judul(text):
    start = text.find("Judul Buku")
    end = text.find("\n", start)
    judul = text[start:end].replace("Judul Buku", "").strip()
    return judul

def extract_isbn(text):
    start = text.find("ISBN")
    end = text.find("\n", start)
    isbn = text[start:end].replace("ISBN", "").strip()
    return isbn

def extract_penulis(text):
    start = text.find("Penulis")
    end = text.find("\n", start)
    penulis = text[start:end].replace("Penulis", "").strip()
    return penulis

def print_info(pdf_file):
    images = pdf_to_img(pdf_file)
    text_data_buku = ""
    for pg, img in enumerate(images):
        text_data_buku += ocr_core(img)

    isbn = extract_isbn(text_data_buku)
    penulis = extract_penulis(text_data_buku)

    print("ISBN:", isbn)
    print("Penulis:", penulis)

def select_pdf_file():
    uploaded = files.upload()
    for file_name in uploaded.keys():
        return file_name

def collect_ground_truth_data():
    ground_truth_data = {}

    print("Silakan unggah file PDF dengan teks asli. Ketik 'selesai' jika sudah selesai.")
    while True:
        file_name = select_pdf_file()
        if file_name:
            # Proses file PDF yang diunggah
            images = pdf_to_img(file_name)
            text_data_buku = ""
            for pg, img in enumerate(images):
                text_data_buku += ocr_core(img)

            # Simpan teks asli dari PDF ke dalam dictionary berdasarkan nama file
            ground_truth_data[file_name] = text_data_buku

            print("File {} berhasil diunggah dan teks asli telah disimpan.".format(file_name))
        else:
            print("Tidak ada file yang diunggah.")

        stop_collecting = input("Apakah Anda ingin berhenti mengumpulkan data? (yes/no): ").lower()
        if stop_collecting == "yes":
            break

    return ground_truth_data

def calculate_word_error_rate(actual_text, ocr_text):
    actual_words = actual_text.lower().split()
    ocr_words = ocr_text.lower().split()

    total_words = len(actual_words)
    word_errors = sum(1 for word in ocr_words if word not in actual_words)

    if total_words == 0:
        word_error_rate = 0
    else:
        word_error_rate = word_errors / total_words

    return word_error_rate

def calculate_recall_precision(ground_truth_data, ocr_data):
    total_ground_truth_words = 0
    total_correctly_detected_words = 0
    total_detected_words = 0

    for file_name, ground_truth_text in ground_truth_data.items():
        ocr_text = ocr_data.get(file_name, "")

        ground_truth_words = set(ground_truth_text.lower().split())
        ocr_words = set(ocr_text.lower().split())

        correctly_detected_words = ground_truth_words.intersection(ocr_words)
        total_correctly_detected_words += len(correctly_detected_words)

        total_ground_truth_words += len(ground_truth_words)
        total_detected_words += len(ocr_words)

    if total_ground_truth_words == 0:
        # Handle the case when ground_truth_data is empty to avoid division by zero
        recall = 0
    else:
        recall = total_correctly_detected_words / total_ground_truth_words

    if total_detected_words == 0:
        # Handle the case when there are no detected words to avoid division by zero
        precision = 0
    else:
        precision = total_correctly_detected_words / total_detected_words

    return recall, precision


if __name__ == "__main__":
    # Tambahkan kode untuk mengumpulkan data teks asli
    ground_truth_data = collect_ground_truth_data()

    # Proses OCR dan evaluasi menggunakan data teks asli
    ocr_results = {}  # Dictionary to store OCR results for each file
    for pdf_file, actual_text in ground_truth_data.items():
        print("Proses file:", pdf_file)
        images = pdf_to_img(pdf_file)
        text_data_buku = ""
        for pg, img in enumerate(images):
            text_data_buku += ocr_core(img)

        isbn = extract_isbn(text_data_buku)
        penulis = extract_penulis(text_data_buku)

        print("ISBN:", isbn)
        print("Penulis:", penulis)

        # Simpan hasil OCR untuk file ini ke dalam dictionary
        ocr_results[pdf_file] = text_data_buku

    # Hitung dan tampilkan recall dan precision
    recall, precision = calculate_recall_precision(ground_truth_data, ocr_results)
    print("Recall: {:.2f}".format(recall))
    print("Precision: {:.2f}".format(precision))
# Out:
# Silakan unggah file PDF dengan teks asli. Ketik 'selesai' jika sudah selesai.
#      <input type="file" id="files-f99a5c92-c843-45ac-91c5-9c1ade50531e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f99a5c92-c843-45ac-91c5-9c1ade50531e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %%
# @title less noise -9
import pdf2image
from PIL import Image
import pytesseract
from google.colab import files

def pdf_to_img(pdf_file):
    return pdf2image.convert_from_path(pdf_file)

def ocr_core(file):
    text = pytesseract.image_to_string(file)
    return text

def extract_judul(text):
    start = text.find("Judul Buku")
    end = text.find("\n", start)
    judul = text[start:end].replace("Judul Buku", "").strip()
    return judul

def extract_isbn(text):
    start = text.find("ISBN")
    end = text.find("\n", start)
    isbn = text[start:end].replace("ISBN", "").strip()
    return isbn

def extract_penulis(text):
    start = text.find("Penulis")
    end = text.find("\n", start)
    penulis = text[start:end].replace("Penulis", "").strip()
    return penulis

def print_info(pdf_file):
    images = pdf_to_img(pdf_file)
    text_data_buku = ""
    for pg, img in enumerate(images):
        text_data_buku += ocr_core(img)

    isbn = extract_isbn(text_data_buku)
    penulis = extract_penulis(text_data_buku)

    print("ISBN:", isbn)
    print("Penulis:", penulis)

def select_pdf_file():
    uploaded = files.upload()
    for file_name in uploaded.keys():
        return file_name

def collect_ground_truth_data():
    ground_truth_data = {}

    print("Silakan unggah file PDF dengan teks asli. Ketik 'selesai' jika sudah selesai.")
    while True:
        file_name = select_pdf_file()
        if file_name:
            # Proses file PDF yang diunggah
            images = pdf_to_img(file_name)
            text_data_buku = ""
            for pg, img in enumerate(images):
                text_data_buku += ocr_core(img)

            # Simpan teks asli dari PDF ke dalam dictionary berdasarkan nama file
            ground_truth_data[file_name] = text_data_buku

            print("File {} berhasil diunggah dan teks asli telah disimpan.".format(file_name))
        else:
            print("Tidak ada file yang diunggah.")

        stop_collecting = input("Apakah Anda ingin berhenti mengumpulkan data? (yes/no): ").lower()
        if stop_collecting == "yes":
            break

    return ground_truth_data

def calculate_word_error_rate(actual_text, ocr_text):
    actual_words = actual_text.lower().split()
    ocr_words = ocr_text.lower().split()

    total_words = len(actual_words)
    word_errors = sum(1 for word in ocr_words if word not in actual_words)

    if total_words == 0:
        word_error_rate = 0
    else:
        word_error_rate = word_errors / total_words

    return word_error_rate

def calculate_recall_precision(ground_truth_data, ocr_data):
    total_ground_truth_words = 0
    total_correctly_detected_words = 0
    total_detected_words = 0

    for file_name, ground_truth_text in ground_truth_data.items():
        ocr_text = ocr_data.get(file_name, "")

        ground_truth_words = set(ground_truth_text.lower().split())
        ocr_words = set(ocr_text.lower().split())

        correctly_detected_words = ground_truth_words.intersection(ocr_words)
        total_correctly_detected_words += len(correctly_detected_words)

        total_ground_truth_words += len(ground_truth_words)
        total_detected_words += len(ocr_words)

    if total_ground_truth_words == 0:
        # Handle the case when ground_truth_data is empty to avoid division by zero
        recall = 0
    else:
        recall = total_correctly_detected_words / total_ground_truth_words

    if total_detected_words == 0:
        # Handle the case when there are no detected words to avoid division by zero
        precision = 0
    else:
        precision = total_correctly_detected_words / total_detected_words

    return recall, precision


if __name__ == "__main__":
    # Tambahkan kode untuk mengumpulkan data teks asli
    ground_truth_data = collect_ground_truth_data()

    # Proses OCR dan evaluasi menggunakan data teks asli
    ocr_results = {}  # Dictionary to store OCR results for each file
    for pdf_file, actual_text in ground_truth_data.items():
        print("Proses file:", pdf_file)
        images = pdf_to_img(pdf_file)
        text_data_buku = ""
        for pg, img in enumerate(images):
            text_data_buku += ocr_core(img)

        isbn = extract_isbn(text_data_buku)
        penulis = extract_penulis(text_data_buku)

        print("ISBN:", isbn)
        print("Penulis:", penulis)

        # Simpan hasil OCR untuk file ini ke dalam dictionary
        ocr_results[pdf_file] = text_data_buku

    # Hitung dan tampilkan recall dan precision
    recall, precision = calculate_recall_precision(ground_truth_data, ocr_results)
    print("Recall: {:.2f}".format(recall))
    print("Precision: {:.2f}".format(precision))
# Out:
# Silakan unggah file PDF dengan teks asli. Ketik 'selesai' jika sudah selesai.
#      <input type="file" id="files-1c28c767-effa-4051-ba57-f8acad0f847d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1c28c767-effa-4051-ba57-f8acad0f847d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %%
# @title scan
# @title less noise
import pdf2image
from PIL import Image
import pytesseract
from google.colab import files

def pdf_to_img(pdf_file):
    return pdf2image.convert_from_path(pdf_file)

def ocr_core(file):
    text = pytesseract.image_to_string(file)
    return text

def extract_judul(text):
    start = text.find("Judul Buku")
    end = text.find("\n", start)
    judul = text[start:end].replace("Judul Buku", "").strip()
    return judul

def extract_isbn(text):
    start = text.find("ISBN")
    end = text.find("\n", start)
    isbn = text[start:end].replace("ISBN", "").strip()
    return isbn

def extract_penulis(text):
    start = text.find("Penulis")
    end = text.find("\n", start)
    penulis = text[start:end].replace("Penulis", "").strip()
    return penulis

def print_info(pdf_file):
    images = pdf_to_img(pdf_file)
    text_data_buku = ""
    for pg, img in enumerate(images):
        text_data_buku += ocr_core(img)

    isbn = extract_isbn(text_data_buku)
    penulis = extract_penulis(text_data_buku)

    print("ISBN:", isbn)
    print("Penulis:", penulis)

def select_pdf_file():
    uploaded = files.upload()
    for file_name in uploaded.keys():
        return file_name

def collect_ground_truth_data():
    ground_truth_data = {}

    print("Silakan unggah file PDF dengan teks asli. Ketik 'selesai' jika sudah selesai.")
    while True:
        file_name = select_pdf_file()
        if file_name:
            # Proses file PDF yang diunggah
            images = pdf_to_img(file_name)
            text_data_buku = ""
            for pg, img in enumerate(images):
                text_data_buku += ocr_core(img)

            # Simpan teks asli dari PDF ke dalam dictionary berdasarkan nama file
            ground_truth_data[file_name] = text_data_buku

            print("File {} berhasil diunggah dan teks asli telah disimpan.".format(file_name))
        else:
            print("Tidak ada file yang diunggah.")

        stop_collecting = input("Apakah Anda ingin berhenti mengumpulkan data? (yes/no): ").lower()
        if stop_collecting == "yes":
            break

    return ground_truth_data

def calculate_word_error_rate(actual_text, ocr_text):
    actual_words = actual_text.lower().split()
    ocr_words = ocr_text.lower().split()

    total_words = len(actual_words)
    word_errors = sum(1 for word in ocr_words if word not in actual_words)

    if total_words == 0:
        word_error_rate = 0
    else:
        word_error_rate = word_errors / total_words

    return word_error_rate

def calculate_recall_precision(ground_truth_data, ocr_data):
    total_ground_truth_words = 0
    total_correctly_detected_words = 0
    total_detected_words = 0

    for file_name, ground_truth_text in ground_truth_data.items():
        ocr_text = ocr_data.get(file_name, "")

        ground_truth_words = set(ground_truth_text.lower().split())
        ocr_words = set(ocr_text.lower().split())

        correctly_detected_words = ground_truth_words.intersection(ocr_words)
        total_correctly_detected_words += len(correctly_detected_words)

        total_ground_truth_words += len(ground_truth_words)
        total_detected_words += len(ocr_words)

    if total_ground_truth_words == 0:
        # Handle the case when ground_truth_data is empty to avoid division by zero
        recall = 0
    else:
        recall = total_correctly_detected_words / total_ground_truth_words

    if total_detected_words == 0:
        # Handle the case when there are no detected words to avoid division by zero
        precision = 0
    else:
        precision = total_correctly_detected_words / total_detected_words

    return recall, precision


if __name__ == "__main__":
    # Tambahkan kode untuk mengumpulkan data teks asli
    ground_truth_data = collect_ground_truth_data()

    # Proses OCR dan evaluasi menggunakan data teks asli
    ocr_results = {}  # Dictionary to store OCR results for each file
    for pdf_file, actual_text in ground_truth_data.items():
        print("Proses file:", pdf_file)
        images = pdf_to_img(pdf_file)
        text_data_buku = ""
        for pg, img in enumerate(images):
            text_data_buku += ocr_core(img)

        isbn = extract_isbn(text_data_buku)
        penulis = extract_penulis(text_data_buku)

        print("ISBN:", isbn)
        print("Penulis:", penulis)

        # Simpan hasil OCR untuk file ini ke dalam dictionary
        ocr_results[pdf_file] = text_data_buku

    # Hitung dan tampilkan recall dan precision
    recall, precision = calculate_recall_precision(ground_truth_data, ocr_results)
    print("Recall: {:.2f}".format(recall))
    print("Precision: {:.2f}".format(precision))
# Out:
# Silakan unggah file PDF dengan teks asli. Ketik 'selesai' jika sudah selesai.
#      <input type="file" id="files-5f460496-c8d9-4db1-ad55-f44fb9daaa3c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5f460496-c8d9-4db1-ad55-f44fb9daaa3c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %%
# @title 10
import pdf2image
from PIL import Image
import pytesseract
from google.colab import files

def pdf_to_img(pdf_file):
    return pdf2image.convert_from_path(pdf_file)

def ocr_core(file):
    text = pytesseract.image_to_string(file)
    return text

def extract_judul(text):
    start = text.find("Judul Buku")
    end = text.find("\n", start)
    judul = text[start:end].replace("Judul Buku", "").strip()
    return judul

def extract_isbn(text):
    start = text.find("ISBN")
    end = text.find("\n", start)
    isbn = text[start:end].replace("ISBN", "").strip()
    return isbn

def extract_penulis(text):
    start = text.find("Penulis")
    end = text.find("\n", start)
    penulis = text[start:end].replace("Penulis", "").strip()
    return penulis

def print_info(pdf_file):
    images = pdf_to_img(pdf_file)
    text_data_buku = ""
    for pg, img in enumerate(images):
        text_data_buku += ocr_core(img)

    isbn = extract_isbn(text_data_buku)
    penulis = extract_penulis(text_data_buku)

    print("ISBN:", isbn)
    print("Penulis:", penulis)

def select_pdf_file():
    uploaded = files.upload()
    for file_name in uploaded.keys():
        return file_name

def collect_ground_truth_data():
    ground_truth_data = {}

    print("Silakan unggah file PDF dengan teks asli. Ketik 'selesai' jika sudah selesai.")
    while True:
        file_name = select_pdf_file()
        if file_name:
            # Proses file PDF yang diunggah
            images = pdf_to_img(file_name)
            text_data_buku = ""
            for pg, img in enumerate(images):
                text_data_buku += ocr_core(img)

            # Simpan teks asli dari PDF ke dalam dictionary berdasarkan nama file
            ground_truth_data[file_name] = text_data_buku

            print("File {} berhasil diunggah dan teks asli telah disimpan.".format(file_name))
        else:
            print("Tidak ada file yang diunggah.")

        stop_collecting = input("Apakah Anda ingin berhenti mengumpulkan data? (yes/no): ").lower()
        if stop_collecting == "yes":
            break

    return ground_truth_data

def calculate_word_error_rate(actual_text, ocr_text):
    actual_words = actual_text.lower().split()
    ocr_words = ocr_text.lower().split()

    total_words = len(actual_words)
    word_errors = sum(1 for word in ocr_words if word not in actual_words)

    if total_words == 0:
        word_error_rate = 0
    else:
        word_error_rate = word_errors / total_words

    return word_error_rate

def calculate_recall_precision(ground_truth_data, ocr_data):
    total_ground_truth_words = 0
    total_correctly_detected_words = 0
    total_detected_words = 0

    for file_name, ground_truth_text in ground_truth_data.items():
        ocr_text = ocr_data.get(file_name, "")

        ground_truth_words = set(ground_truth_text.lower().split())
        ocr_words = set(ocr_text.lower().split())

        correctly_detected_words = ground_truth_words.intersection(ocr_words)
        total_correctly_detected_words += len(correctly_detected_words)

        total_ground_truth_words += len(ground_truth_words)
        total_detected_words += len(ocr_words)

    if total_ground_truth_words == 0:
        # Handle the case when ground_truth_data is empty to avoid division by zero
        recall = 0
    else:
        recall = total_correctly_detected_words / total_ground_truth_words

    if total_detected_words == 0:
        # Handle the case when there are no detected words to avoid division by zero
        precision = 0
    else:
        precision = total_correctly_detected_words / total_detected_words

    return recall, precision


if __name__ == "__main__":
    # Tambahkan kode untuk mengumpulkan data teks asli
    ground_truth_data = collect_ground_truth_data()

    # Proses OCR dan evaluasi menggunakan data teks asli
    ocr_results = {}  # Dictionary to store OCR results for each file
    for pdf_file, actual_text in ground_truth_data.items():
        print("Proses file:", pdf_file)
        images = pdf_to_img(pdf_file)
        text_data_buku = ""
        for pg, img in enumerate(images):
            text_data_buku += ocr_core(img)

        isbn = extract_isbn(text_data_buku)
        penulis = extract_penulis(text_data_buku)

        print("ISBN:", isbn)
        print("Penulis:", penulis)

        # Simpan hasil OCR untuk file ini ke dalam dictionary
        ocr_results[pdf_file] = text_data_buku

    # Hitung dan tampilkan recall dan precision
    recall, precision = calculate_recall_precision(ground_truth_data, ocr_results)
    print("Recall: {:.2f}".format(recall))
    print("Precision: {:.2f}".format(precision))
# Out:
# Silakan unggah file PDF dengan teks asli. Ketik 'selesai' jika sudah selesai.
#      <input type="file" id="files-cd88d713-139d-47f2-a776-d71807b99a41" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cd88d713-139d-47f2-a776-d71807b99a41">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %%
# @title 30
import pdf2image
from PIL import Image
import pytesseract
from google.colab import files

def pdf_to_img(pdf_file):
    return pdf2image.convert_from_path(pdf_file)

def ocr_core(file):
    text = pytesseract.image_to_string(file)
    return text

def extract_judul(text):
    start = text.find("Judul Buku")
    end = text.find("\n", start)
    judul = text[start:end].replace("Judul Buku", "").strip()
    return judul

def extract_isbn(text):
    start = text.find("ISBN")
    end = text.find("\n", start)
    isbn = text[start:end].replace("ISBN", "").strip()
    return isbn

def extract_penulis(text):
    start = text.find("Penulis")
    end = text.find("\n", start)
    penulis = text[start:end].replace("Penulis", "").strip()
    return penulis

def print_info(pdf_file):
    images = pdf_to_img(pdf_file)
    text_data_buku = ""
    for pg, img in enumerate(images):
        text_data_buku += ocr_core(img)

    isbn = extract_isbn(text_data_buku)
    penulis = extract_penulis(text_data_buku)

    print("ISBN:", isbn)
    print("Penulis:", penulis)

def select_pdf_file():
    uploaded = files.upload()
    for file_name in uploaded.keys():
        return file_name

def collect_ground_truth_data():
    ground_truth_data = {}

    print("Silakan unggah file PDF dengan teks asli. Ketik 'selesai' jika sudah selesai.")
    while True:
        file_name = select_pdf_file()
        if file_name:
            # Proses file PDF yang diunggah
            images = pdf_to_img(file_name)
            text_data_buku = ""
            for pg, img in enumerate(images):
                text_data_buku += ocr_core(img)

            # Simpan teks asli dari PDF ke dalam dictionary berdasarkan nama file
            ground_truth_data[file_name] = text_data_buku

            print("File {} berhasil diunggah dan teks asli telah disimpan.".format(file_name))
        else:
            print("Tidak ada file yang diunggah.")

        stop_collecting = input("Apakah Anda ingin berhenti mengumpulkan data? (yes/no): ").lower()
        if stop_collecting == "yes":
            break

    return ground_truth_data

def calculate_word_error_rate(actual_text, ocr_text):
    actual_words = actual_text.lower().split()
    ocr_words = ocr_text.lower().split()

    total_words = len(actual_words)
    word_errors = sum(1 for word in ocr_words if word not in actual_words)

    if total_words == 0:
        word_error_rate = 0
    else:
        word_error_rate = word_errors / total_words

    return word_error_rate

def calculate_recall_precision(ground_truth_data, ocr_data):
    total_ground_truth_words = 0
    total_correctly_detected_words = 0
    total_detected_words = 0

    for file_name, ground_truth_text in ground_truth_data.items():
        ocr_text = ocr_data.get(file_name, "")

        ground_truth_words = set(ground_truth_text.lower().split())
        ocr_words = set(ocr_text.lower().split())

        correctly_detected_words = ground_truth_words.intersection(ocr_words)
        total_correctly_detected_words += len(correctly_detected_words)

        total_ground_truth_words += len(ground_truth_words)
        total_detected_words += len(ocr_words)

    if total_ground_truth_words == 0:
        # Handle the case when ground_truth_data is empty to avoid division by zero
        recall = 0
    else:
        recall = total_correctly_detected_words / total_ground_truth_words

    if total_detected_words == 0:
        # Handle the case when there are no detected words to avoid division by zero
        precision = 0
    else:
        precision = total_correctly_detected_words / total_detected_words

    return recall, precision


if __name__ == "__main__":
    # Tambahkan kode untuk mengumpulkan data teks asli
    ground_truth_data = collect_ground_truth_data()

    # Proses OCR dan evaluasi menggunakan data teks asli
    ocr_results = {}  # Dictionary to store OCR results for each file
    for pdf_file, actual_text in ground_truth_data.items():
        print("Proses file:", pdf_file)
        images = pdf_to_img(pdf_file)
        text_data_buku = ""
        for pg, img in enumerate(images):
            text_data_buku += ocr_core(img)

        isbn = extract_isbn(text_data_buku)
        penulis = extract_penulis(text_data_buku)

        print("ISBN:", isbn)
        print("Penulis:", penulis)

        # Simpan hasil OCR untuk file ini ke dalam dictionary
        ocr_results[pdf_file] = text_data_buku

    # Hitung dan tampilkan recall dan precision
    recall, precision = calculate_recall_precision(ground_truth_data, ocr_results)
    print("Recall: {:.2f}".format(recall))
    print("Precision: {:.2f}".format(precision))
# Out:
# Silakan unggah file PDF dengan teks asli. Ketik 'selesai' jika sudah selesai.
#      <input type="file" id="files-114627ac-d339-4f73-8647-38db66cc14d6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-114627ac-d339-4f73-8647-38db66cc14d6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %%
# @title 60
import pdf2image
from PIL import Image
import pytesseract
from google.colab import files

def pdf_to_img(pdf_file):
    return pdf2image.convert_from_path(pdf_file)

def ocr_core(file):
    text = pytesseract.image_to_string(file)
    return text

def extract_judul(text):
    start = text.find("Judul Buku")
    end = text.find("\n", start)
    judul = text[start:end].replace("Judul Buku", "").strip()
    return judul

def extract_isbn(text):
    start = text.find("ISBN")
    end = text.find("\n", start)
    isbn = text[start:end].replace("ISBN", "").strip()
    return isbn

def extract_penulis(text):
    start = text.find("Penulis")
    end = text.find("\n", start)
    penulis = text[start:end].replace("Penulis", "").strip()
    return penulis

def print_info(pdf_file):
    images = pdf_to_img(pdf_file)
    text_data_buku = ""
    for pg, img in enumerate(images):
        text_data_buku += ocr_core(img)

    isbn = extract_isbn(text_data_buku)
    penulis = extract_penulis(text_data_buku)

    print("ISBN:", isbn)
    print("Penulis:", penulis)

def select_pdf_file():
    uploaded = files.upload()
    for file_name in uploaded.keys():
        return file_name

def collect_ground_truth_data():
    ground_truth_data = {}

    print("Silakan unggah file PDF dengan teks asli. Ketik 'selesai' jika sudah selesai.")
    while True:
        file_name = select_pdf_file()
        if file_name:
            # Proses file PDF yang diunggah
            images = pdf_to_img(file_name)
            text_data_buku = ""
            for pg, img in enumerate(images):
                text_data_buku += ocr_core(img)

            # Simpan teks asli dari PDF ke dalam dictionary berdasarkan nama file
            ground_truth_data[file_name] = text_data_buku

            print("File {} berhasil diunggah dan teks asli telah disimpan.".format(file_name))
        else:
            print("Tidak ada file yang diunggah.")

        stop_collecting = input("Apakah Anda ingin berhenti mengumpulkan data? (yes/no): ").lower()
        if stop_collecting == "yes":
            break

    return ground_truth_data

def calculate_word_error_rate(actual_text, ocr_text):
    actual_words = actual_text.lower().split()
    ocr_words = ocr_text.lower().split()

    total_words = len(actual_words)
    word_errors = sum(1 for word in ocr_words if word not in actual_words)

    if total_words == 0:
        word_error_rate = 0
    else:
        word_error_rate = word_errors / total_words

    return word_error_rate

def calculate_recall_precision(ground_truth_data, ocr_data):
    total_ground_truth_words = 0
    total_correctly_detected_words = 0
    total_detected_words = 0

    for file_name, ground_truth_text in ground_truth_data.items():
        ocr_text = ocr_data.get(file_name, "")

        ground_truth_words = set(ground_truth_text.lower().split())
        ocr_words = set(ocr_text.lower().split())

        correctly_detected_words = ground_truth_words.intersection(ocr_words)
        total_correctly_detected_words += len(correctly_detected_words)

        total_ground_truth_words += len(ground_truth_words)
        total_detected_words += len(ocr_words)

    if total_ground_truth_words == 0:
        # Handle the case when ground_truth_data is empty to avoid division by zero
        recall = 0
    else:
        recall = total_correctly_detected_words / total_ground_truth_words

    if total_detected_words == 0:
        # Handle the case when there are no detected words to avoid division by zero
        precision = 0
    else:
        precision = total_correctly_detected_words / total_detected_words

    return recall, precision


if __name__ == "__main__":
    # Tambahkan kode untuk mengumpulkan data teks asli
    ground_truth_data = collect_ground_truth_data()

    # Proses OCR dan evaluasi menggunakan data teks asli
    ocr_results = {}  # Dictionary to store OCR results for each file
    for pdf_file, actual_text in ground_truth_data.items():
        print("Proses file:", pdf_file)
        images = pdf_to_img(pdf_file)
        text_data_buku = ""
        for pg, img in enumerate(images):
            text_data_buku += ocr_core(img)

        isbn = extract_isbn(text_data_buku)
        penulis = extract_penulis(text_data_buku)

        print("ISBN:", isbn)
        print("Penulis:", penulis)

        # Simpan hasil OCR untuk file ini ke dalam dictionary
        ocr_results[pdf_file] = text_data_buku

    # Hitung dan tampilkan recall dan precision
    recall, precision = calculate_recall_precision(ground_truth_data, ocr_results)
    print("Recall: {:.2f}".format(recall))
    print("Precision: {:.2f}".format(precision))
# Out:
# Silakan unggah file PDF dengan teks asli. Ketik 'selesai' jika sudah selesai.
#      <input type="file" id="files-71937827-3d22-437b-9877-2ef11a7ad24c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-71937827-3d22-437b-9877-2ef11a7ad24c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %%
# @title 90
import pdf2image
from PIL import Image
import pytesseract
from google.colab import files

def pdf_to_img(pdf_file):
    return pdf2image.convert_from_path(pdf_file)

def ocr_core(file):
    text = pytesseract.image_to_string(file)
    return text

def extract_judul(text):
    start = text.find("Judul Buku")
    end = text.find("\n", start)
    judul = text[start:end].replace("Judul Buku", "").strip()
    return judul

def extract_isbn(text):
    start = text.find("ISBN")
    end = text.find("\n", start)
    isbn = text[start:end].replace("ISBN", "").strip()
    return isbn

def extract_penulis(text):
    start = text.find("Penulis")
    end = text.find("\n", start)
    penulis = text[start:end].replace("Penulis", "").strip()
    return penulis

def print_info(pdf_file):
    images = pdf_to_img(pdf_file)
    text_data_buku = ""
    for pg, img in enumerate(images):
        text_data_buku += ocr_core(img)

    isbn = extract_isbn(text_data_buku)
    penulis = extract_penulis(text_data_buku)

    print("ISBN:", isbn)
    print("Penulis:", penulis)

def select_pdf_file():
    uploaded = files.upload()
    for file_name in uploaded.keys():
        return file_name

def collect_ground_truth_data():
    ground_truth_data = {}

    print("Silakan unggah file PDF dengan teks asli. Ketik 'selesai' jika sudah selesai.")
    while True:
        file_name = select_pdf_file()
        if file_name:
            # Proses file PDF yang diunggah
            images = pdf_to_img(file_name)
            text_data_buku = ""
            for pg, img in enumerate(images):
                text_data_buku += ocr_core(img)

            # Simpan teks asli dari PDF ke dalam dictionary berdasarkan nama file
            ground_truth_data[file_name] = text_data_buku

            print("File {} berhasil diunggah dan teks asli telah disimpan.".format(file_name))
        else:
            print("Tidak ada file yang diunggah.")

        stop_collecting = input("Apakah Anda ingin berhenti mengumpulkan data? (yes/no): ").lower()
        if stop_collecting == "yes":
            break

    return ground_truth_data

def calculate_word_error_rate(actual_text, ocr_text):
    actual_words = actual_text.lower().split()
    ocr_words = ocr_text.lower().split()

    total_words = len(actual_words)
    word_errors = sum(1 for word in ocr_words if word not in actual_words)

    if total_words == 0:
        word_error_rate = 0
    else:
        word_error_rate = word_errors / total_words

    return word_error_rate

def calculate_recall_precision(ground_truth_data, ocr_data):
    total_ground_truth_words = 0
    total_correctly_detected_words = 0
    total_detected_words = 0

    for file_name, ground_truth_text in ground_truth_data.items():
        ocr_text = ocr_data.get(file_name, "")

        ground_truth_words = set(ground_truth_text.lower().split())
        ocr_words = set(ocr_text.lower().split())

        correctly_detected_words = ground_truth_words.intersection(ocr_words)
        total_correctly_detected_words += len(correctly_detected_words)

        total_ground_truth_words += len(ground_truth_words)
        total_detected_words += len(ocr_words)

    if total_ground_truth_words == 0:
        # Handle the case when ground_truth_data is empty to avoid division by zero
        recall = 0
    else:
        recall = total_correctly_detected_words / total_ground_truth_words

    if total_detected_words == 0:
        # Handle the case when there are no detected words to avoid division by zero
        precision = 0
    else:
        precision = total_correctly_detected_words / total_detected_words

    return recall, precision


if __name__ == "__main__":
    # Tambahkan kode untuk mengumpulkan data teks asli
    ground_truth_data = collect_ground_truth_data()

    # Proses OCR dan evaluasi menggunakan data teks asli
    ocr_results = {}  # Dictionary to store OCR results for each file
    for pdf_file, actual_text in ground_truth_data.items():
        print("Proses file:", pdf_file)
        images = pdf_to_img(pdf_file)
        text_data_buku = ""
        for pg, img in enumerate(images):
            text_data_buku += ocr_core(img)

        isbn = extract_isbn(text_data_buku)
        penulis = extract_penulis(text_data_buku)

        print("ISBN:", isbn)
        print("Penulis:", penulis)

        # Simpan hasil OCR untuk file ini ke dalam dictionary
        ocr_results[pdf_file] = text_data_buku

    # Hitung dan tampilkan recall dan precision
    recall, precision = calculate_recall_precision(ground_truth_data, ocr_results)
    print("Recall: {:.2f}".format(recall))
    print("Precision: {:.2f}".format(precision))
# Out:
# Silakan unggah file PDF dengan teks asli. Ketik 'selesai' jika sudah selesai.
#      <input type="file" id="files-3735b0b0-7087-4909-9ef4-21bd7177e767" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3735b0b0-7087-4909-9ef4-21bd7177e767">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %%
# @title 180
import pdf2image
from PIL import Image
import pytesseract
from google.colab import files

def pdf_to_img(pdf_file):
    return pdf2image.convert_from_path(pdf_file)

def ocr_core(file):
    text = pytesseract.image_to_string(file)
    return text

def extract_judul(text):
    start = text.find("Judul Buku")
    end = text.find("\n", start)
    judul = text[start:end].replace("Judul Buku", "").strip()
    return judul

def extract_isbn(text):
    start = text.find("ISBN")
    end = text.find("\n", start)
    isbn = text[start:end].replace("ISBN", "").strip()
    return isbn

def extract_penulis(text):
    start = text.find("Penulis")
    end = text.find("\n", start)
    penulis = text[start:end].replace("Penulis", "").strip()
    return penulis

def print_info(pdf_file):
    images = pdf_to_img(pdf_file)
    text_data_buku = ""
    for pg, img in enumerate(images):
        text_data_buku += ocr_core(img)

    isbn = extract_isbn(text_data_buku)
    penulis = extract_penulis(text_data_buku)

    print("ISBN:", isbn)
    print("Penulis:", penulis)

def select_pdf_file():
    uploaded = files.upload()
    for file_name in uploaded.keys():
        return file_name

def collect_ground_truth_data():
    ground_truth_data = {}

    print("Silakan unggah file PDF dengan teks asli. Ketik 'selesai' jika sudah selesai.")
    while True:
        file_name = select_pdf_file()
        if file_name:
            # Proses file PDF yang diunggah
            images = pdf_to_img(file_name)
            text_data_buku = ""
            for pg, img in enumerate(images):
                text_data_buku += ocr_core(img)

            # Simpan teks asli dari PDF ke dalam dictionary berdasarkan nama file
            ground_truth_data[file_name] = text_data_buku

            print("File {} berhasil diunggah dan teks asli telah disimpan.".format(file_name))
        else:
            print("Tidak ada file yang diunggah.")

        stop_collecting = input("Apakah Anda ingin berhenti mengumpulkan data? (yes/no): ").lower()
        if stop_collecting == "yes":
            break

    return ground_truth_data

def calculate_word_error_rate(actual_text, ocr_text):
    actual_words = actual_text.lower().split()
    ocr_words = ocr_text.lower().split()

    total_words = len(actual_words)
    word_errors = sum(1 for word in ocr_words if word not in actual_words)

    if total_words == 0:
        word_error_rate = 0
    else:
        word_error_rate = word_errors / total_words

    return word_error_rate

def calculate_recall_precision(ground_truth_data, ocr_data):
    total_ground_truth_words = 0
    total_correctly_detected_words = 0
    total_detected_words = 0

    for file_name, ground_truth_text in ground_truth_data.items():
        ocr_text = ocr_data.get(file_name, "")

        ground_truth_words = set(ground_truth_text.lower().split())
        ocr_words = set(ocr_text.lower().split())

        correctly_detected_words = ground_truth_words.intersection(ocr_words)
        total_correctly_detected_words += len(correctly_detected_words)

        total_ground_truth_words += len(ground_truth_words)
        total_detected_words += len(ocr_words)

    if total_ground_truth_words == 0:
        # Handle the case when ground_truth_data is empty to avoid division by zero
        recall = 0
    else:
        recall = total_correctly_detected_words / total_ground_truth_words

    if total_detected_words == 0:
        # Handle the case when there are no detected words to avoid division by zero
        precision = 0
    else:
        precision = total_correctly_detected_words / total_detected_words

    return recall, precision


if __name__ == "__main__":
    # Tambahkan kode untuk mengumpulkan data teks asli
    ground_truth_data = collect_ground_truth_data()

    # Proses OCR dan evaluasi menggunakan data teks asli
    ocr_results = {}  # Dictionary to store OCR results for each file
    for pdf_file, actual_text in ground_truth_data.items():
        print("Proses file:", pdf_file)
        images = pdf_to_img(pdf_file)
        text_data_buku = ""
        for pg, img in enumerate(images):
            text_data_buku += ocr_core(img)

        isbn = extract_isbn(text_data_buku)
        penulis = extract_penulis(text_data_buku)

        print("ISBN:", isbn)
        print("Penulis:", penulis)

        # Simpan hasil OCR untuk file ini ke dalam dictionary
        ocr_results[pdf_file] = text_data_buku

    # Hitung dan tampilkan recall dan precision
    recall, precision = calculate_recall_precision(ground_truth_data, ocr_results)
    print("Recall: {:.2f}".format(recall))
    print("Precision: {:.2f}".format(precision))
# Out:
# Silakan unggah file PDF dengan teks asli. Ketik 'selesai' jika sudah selesai.
#      <input type="file" id="files-aa5aceab-f42c-4069-88fa-a617d2b43ad7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-aa5aceab-f42c-4069-88fa-a617d2b43ad7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %%
# @title 270
import pdf2image
from PIL import Image
import pytesseract
from google.colab import files

def pdf_to_img(pdf_file):
    return pdf2image.convert_from_path(pdf_file)

def ocr_core(file):
    text = pytesseract.image_to_string(file)
    return text

def extract_judul(text):
    start = text.find("Judul Buku")
    end = text.find("\n", start)
    judul = text[start:end].replace("Judul Buku", "").strip()
    return judul

def extract_isbn(text):
    start = text.find("ISBN")
    end = text.find("\n", start)
    isbn = text[start:end].replace("ISBN", "").strip()
    return isbn

def extract_penulis(text):
    start = text.find("Penulis")
    end = text.find("\n", start)
    penulis = text[start:end].replace("Penulis", "").strip()
    return penulis

def print_info(pdf_file):
    images = pdf_to_img(pdf_file)
    text_data_buku = ""
    for pg, img in enumerate(images):
        text_data_buku += ocr_core(img)

    isbn = extract_isbn(text_data_buku)
    penulis = extract_penulis(text_data_buku)

    print("ISBN:", isbn)
    print("Penulis:", penulis)

def select_pdf_file():
    uploaded = files.upload()
    for file_name in uploaded.keys():
        return file_name

def collect_ground_truth_data():
    ground_truth_data = {}

    print("Silakan unggah file PDF dengan teks asli. Ketik 'selesai' jika sudah selesai.")
    while True:
        file_name = select_pdf_file()
        if file_name:
            # Proses file PDF yang diunggah
            images = pdf_to_img(file_name)
            text_data_buku = ""
            for pg, img in enumerate(images):
                text_data_buku += ocr_core(img)

            # Simpan teks asli dari PDF ke dalam dictionary berdasarkan nama file
            ground_truth_data[file_name] = text_data_buku

            print("File {} berhasil diunggah dan teks asli telah disimpan.".format(file_name))
        else:
            print("Tidak ada file yang diunggah.")

        stop_collecting = input("Apakah Anda ingin berhenti mengumpulkan data? (yes/no): ").lower()
        if stop_collecting == "yes":
            break

    return ground_truth_data

def calculate_word_error_rate(actual_text, ocr_text):
    actual_words = actual_text.lower().split()
    ocr_words = ocr_text.lower().split()

    total_words = len(actual_words)
    word_errors = sum(1 for word in ocr_words if word not in actual_words)

    if total_words == 0:
        word_error_rate = 0
    else:
        word_error_rate = word_errors / total_words

    return word_error_rate

def calculate_recall_precision(ground_truth_data, ocr_data):
    total_ground_truth_words = 0
    total_correctly_detected_words = 0
    total_detected_words = 0

    for file_name, ground_truth_text in ground_truth_data.items():
        ocr_text = ocr_data.get(file_name, "")

        ground_truth_words = set(ground_truth_text.lower().split())
        ocr_words = set(ocr_text.lower().split())

        correctly_detected_words = ground_truth_words.intersection(ocr_words)
        total_correctly_detected_words += len(correctly_detected_words)

        total_ground_truth_words += len(ground_truth_words)
        total_detected_words += len(ocr_words)

    if total_ground_truth_words == 0:
        # Handle the case when ground_truth_data is empty to avoid division by zero
        recall = 0
    else:
        recall = total_correctly_detected_words / total_ground_truth_words

    if total_detected_words == 0:
        # Handle the case when there are no detected words to avoid division by zero
        precision = 0
    else:
        precision = total_correctly_detected_words / total_detected_words

    return recall, precision


if __name__ == "__main__":
    # Tambahkan kode untuk mengumpulkan data teks asli
    ground_truth_data = collect_ground_truth_data()

    # Proses OCR dan evaluasi menggunakan data teks asli
    ocr_results = {}  # Dictionary to store OCR results for each file
    for pdf_file, actual_text in ground_truth_data.items():
        print("Proses file:", pdf_file)
        images = pdf_to_img(pdf_file)
        text_data_buku = ""
        for pg, img in enumerate(images):
            text_data_buku += ocr_core(img)

        isbn = extract_isbn(text_data_buku)
        penulis = extract_penulis(text_data_buku)

        print("ISBN:", isbn)
        print("Penulis:", penulis)

        # Simpan hasil OCR untuk file ini ke dalam dictionary
        ocr_results[pdf_file] = text_data_buku

    # Hitung dan tampilkan recall dan precision
    recall, precision = calculate_recall_precision(ground_truth_data, ocr_results)
    print("Recall: {:.2f}".format(recall))
    print("Precision: {:.2f}".format(precision))
# Out:
# Silakan unggah file PDF dengan teks asli. Ketik 'selesai' jika sudah selesai.
#      <input type="file" id="files-a2e6047e-8730-4d27-960e-ad70ccdae7e7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a2e6047e-8730-4d27-960e-ad70ccdae7e7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %% [markdown]
# # Pengujian image File

# %%
# @title noise
import pdf2image
from PIL import Image
import pytesseract
from google.colab import files
import os

def pdf_to_img(pdf_file):
    # return pdf2image.convert_from_path(pdf_file)
    return pdf_file

def ocr_core(file):
    text = pytesseract.image_to_string(file)
    return text

def extract_isbn(text):
    start = text.find("ISBN")
    end = text.find("\n", start)
    isbn = text[start:end].replace("ISBN", "").strip()
    return isbn

def extract_penulis(text):
    start = text.find("Penulis")
    end = text.find("\n", start)
    penulis = text[start:end].replace("Penulis", "").strip()
    return penulis

def print_info(pdf_file):
    text_data_buku = ""
    text_data_buku += ocr_core(pdf_file)

    isbn = extract_isbn(text_data_buku)
    penulis = extract_penulis(text_data_buku)

    print("ISBN:", isbn)
    print("Penulis:", penulis)

def select_pdf_file():
    uploaded = files.upload()
    for file_name in uploaded.keys():
        return file_name

def collect_ground_truth_data():
    ground_truth_data = {}

    print("Please upload PDF files. Type 'done' when finished.")
    while True:
        pdf_file = select_pdf_file()
        if pdf_file:
            ground_truth_data[pdf_file] = pdf_file
            print("File {} uploaded.".format(pdf_file))
        else:
            print("No PDF file uploaded.")

        stop_collecting = input("Do you want to stop collecting data? (yes/no): ").lower()
        if stop_collecting == "yes":
            break

    return ground_truth_data

if __name__ == "__main__":
    ground_truth_data = collect_ground_truth_data()

    for pdf_file in ground_truth_data.values():
        print("Processing PDF:", pdf_file)
        print_info(pdf_file)
# Out:
# Please upload PDF files. Type 'done' when finished.
#      <input type="file" id="files-f6c4a8b4-f275-4315-981a-f80b7a47a009" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f6c4a8b4-f275-4315-981a-f80b7a47a009">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %%
# @title less noise
import pdf2image
from PIL import Image
import pytesseract
from google.colab import files
import os

def pdf_to_img(pdf_file):
    # return pdf2image.convert_from_path(pdf_file)
    return pdf_file

def ocr_core(file):
    text = pytesseract.image_to_string(file)
    return text

def extract_isbn(text):
    start = text.find("ISBN")
    end = text.find("\n", start)
    isbn = text[start:end].replace("ISBN", "").strip()
    return isbn

def extract_penulis(text):
    start = text.find("Penulis")
    end = text.find("\n", start)
    penulis = text[start:end].replace("Penulis", "").strip()
    return penulis

def print_info(pdf_file):
    text_data_buku = ""
    text_data_buku += ocr_core(pdf_file)

    isbn = extract_isbn(text_data_buku)
    penulis = extract_penulis(text_data_buku)

    print("ISBN:", isbn)
    print("Penulis:", penulis)

def select_pdf_file():
    uploaded = files.upload()
    for file_name in uploaded.keys():
        return file_name

def collect_ground_truth_data():
    ground_truth_data = {}

    print("Please upload PDF files. Type 'done' when finished.")
    while True:
        pdf_file = select_pdf_file()
        if pdf_file:
            ground_truth_data[pdf_file] = pdf_file
            print("File {} uploaded.".format(pdf_file))
        else:
            print("No PDF file uploaded.")

        stop_collecting = input("Do you want to stop collecting data? (yes/no): ").lower()
        if stop_collecting == "yes":
            break

    return ground_truth_data

if __name__ == "__main__":
    ground_truth_data = collect_ground_truth_data()

    for pdf_file in ground_truth_data.values():
        print("Processing PDF:", pdf_file)
        print_info(pdf_file)
# Out:
# Please upload PDF files. Type 'done' when finished.
#      <input type="file" id="files-1b62ed57-8083-4af3-ace7-07b27e5a664d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1b62ed57-8083-4af3-ace7-07b27e5a664d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %%
# @title scan
import pdf2image
from PIL import Image
import pytesseract
from google.colab import files
import os

def pdf_to_img(pdf_file):
    # return pdf2image.convert_from_path(pdf_file)
    return pdf_file

def ocr_core(file):
    text = pytesseract.image_to_string(file)
    return text

def extract_isbn(text):
    start = text.find("ISBN")
    end = text.find("\n", start)
    isbn = text[start:end].replace("ISBN", "").strip()
    return isbn

def extract_penulis(text):
    start = text.find("Penulis")
    end = text.find("\n", start)
    penulis = text[start:end].replace("Penulis", "").strip()
    return penulis

def print_info(pdf_file):
    text_data_buku = ""
    text_data_buku += ocr_core(pdf_file)

    isbn = extract_isbn(text_data_buku)
    penulis = extract_penulis(text_data_buku)

    print("ISBN:", isbn)
    print("Penulis:", penulis)

def select_pdf_file():
    uploaded = files.upload()
    for file_name in uploaded.keys():
        return file_name

def collect_ground_truth_data():
    ground_truth_data = {}

    print("Please upload PDF files. Type 'done' when finished.")
    while True:
        pdf_file = select_pdf_file()
        if pdf_file:
            ground_truth_data[pdf_file] = pdf_file
            print("File {} uploaded.".format(pdf_file))
        else:
            print("No PDF file uploaded.")

        stop_collecting = input("Do you want to stop collecting data? (yes/no): ").lower()
        if stop_collecting == "yes":
            break

    return ground_truth_data

if __name__ == "__main__":
    ground_truth_data = collect_ground_truth_data()

    for pdf_file in ground_truth_data.values():
        print("Processing PDF:", pdf_file)
        print_info(pdf_file)
# Out:
# Please upload PDF files. Type 'done' when finished.
#      <input type="file" id="files-256be086-47bf-4d4a-a777-16e8ef75f45b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-256be086-47bf-4d4a-a777-16e8ef75f45b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %%
# @title 10
import pdf2image
from PIL import Image
import pytesseract
from google.colab import files
import os

def pdf_to_img(pdf_file):
    # return pdf2image.convert_from_path(pdf_file)
    return pdf_file

def ocr_core(file):
    text = pytesseract.image_to_string(file)
    return text

def extract_isbn(text):
    start = text.find("ISBN")
    end = text.find("\n", start)
    isbn = text[start:end].replace("ISBN", "").strip()
    return isbn

def extract_penulis(text):
    start = text.find("Penulis")
    end = text.find("\n", start)
    penulis = text[start:end].replace("Penulis", "").strip()
    return penulis

def print_info(pdf_file):
    text_data_buku = ""
    text_data_buku += ocr_core(pdf_file)

    isbn = extract_isbn(text_data_buku)
    penulis = extract_penulis(text_data_buku)

    print("ISBN:", isbn)
    print("Penulis:", penulis)

def select_pdf_file():
    uploaded = files.upload()
    for file_name in uploaded.keys():
        return file_name

def collect_ground_truth_data():
    ground_truth_data = {}

    print("Please upload PDF files. Type 'done' when finished.")
    while True:
        pdf_file = select_pdf_file()
        if pdf_file:
            ground_truth_data[pdf_file] = pdf_file
            print("File {} uploaded.".format(pdf_file))
        else:
            print("No PDF file uploaded.")

        stop_collecting = input("Do you want to stop collecting data? (yes/no): ").lower()
        if stop_collecting == "yes":
            break

    return ground_truth_data

if __name__ == "__main__":
    ground_truth_data = collect_ground_truth_data()

    for pdf_file in ground_truth_data.values():
        print("Processing PDF:", pdf_file)
        print_info(pdf_file)
# Out:
# Please upload PDF files. Type 'done' when finished.
#      <input type="file" id="files-89b2d724-f77e-40b6-8021-c726b791845c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-89b2d724-f77e-40b6-8021-c726b791845c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %%
# @title 30
import pdf2image
from PIL import Image
import pytesseract
from google.colab import files
import os

def pdf_to_img(pdf_file):
    # return pdf2image.convert_from_path(pdf_file)
    return pdf_file

def ocr_core(file):
    text = pytesseract.image_to_string(file)
    return text

def extract_isbn(text):
    start = text.find("ISBN")
    end = text.find("\n", start)
    isbn = text[start:end].replace("ISBN", "").strip()
    return isbn

def extract_penulis(text):
    start = text.find("Penulis")
    end = text.find("\n", start)
    penulis = text[start:end].replace("Penulis", "").strip()
    return penulis

def print_info(pdf_file):
    text_data_buku = ""
    text_data_buku += ocr_core(pdf_file)

    isbn = extract_isbn(text_data_buku)
    penulis = extract_penulis(text_data_buku)

    print("ISBN:", isbn)
    print("Penulis:", penulis)

def select_pdf_file():
    uploaded = files.upload()
    for file_name in uploaded.keys():
        return file_name

def collect_ground_truth_data():
    ground_truth_data = {}

    print("Please upload PDF files. Type 'done' when finished.")
    while True:
        pdf_file = select_pdf_file()
        if pdf_file:
            ground_truth_data[pdf_file] = pdf_file
            print("File {} uploaded.".format(pdf_file))
        else:
            print("No PDF file uploaded.")

        stop_collecting = input("Do you want to stop collecting data? (yes/no): ").lower()
        if stop_collecting == "yes":
            break

    return ground_truth_data

if __name__ == "__main__":
    ground_truth_data = collect_ground_truth_data()

    for pdf_file in ground_truth_data.values():
        print("Processing PDF:", pdf_file)
        print_info(pdf_file)
# Out:
# Please upload PDF files. Type 'done' when finished.
#      <input type="file" id="files-7290762c-a552-41aa-86b5-028b04b121b6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7290762c-a552-41aa-86b5-028b04b121b6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %%
# @title 60
import pdf2image
from PIL import Image
import pytesseract
from google.colab import files
import os

def pdf_to_img(pdf_file):
    # return pdf2image.convert_from_path(pdf_file)
    return pdf_file

def ocr_core(file):
    text = pytesseract.image_to_string(file)
    return text

def extract_isbn(text):
    start = text.find("ISBN")
    end = text.find("\n", start)
    isbn = text[start:end].replace("ISBN", "").strip()
    return isbn

def extract_penulis(text):
    start = text.find("Penulis")
    end = text.find("\n", start)
    penulis = text[start:end].replace("Penulis", "").strip()
    return penulis

def print_info(pdf_file):
    text_data_buku = ""
    text_data_buku += ocr_core(pdf_file)

    isbn = extract_isbn(text_data_buku)
    penulis = extract_penulis(text_data_buku)

    print("ISBN:", isbn)
    print("Penulis:", penulis)

def select_pdf_file():
    uploaded = files.upload()
    for file_name in uploaded.keys():
        return file_name

def collect_ground_truth_data():
    ground_truth_data = {}

    print("Please upload PDF files. Type 'done' when finished.")
    while True:
        pdf_file = select_pdf_file()
        if pdf_file:
            ground_truth_data[pdf_file] = pdf_file
            print("File {} uploaded.".format(pdf_file))
        else:
            print("No PDF file uploaded.")

        stop_collecting = input("Do you want to stop collecting data? (yes/no): ").lower()
        if stop_collecting == "yes":
            break

    return ground_truth_data

if __name__ == "__main__":
    ground_truth_data = collect_ground_truth_data()

    for pdf_file in ground_truth_data.values():
        print("Processing PDF:", pdf_file)
        print_info(pdf_file)
# Out:
# Please upload PDF files. Type 'done' when finished.
#      <input type="file" id="files-ed1ffb93-aa9c-4de2-b8ad-5f2843e0695a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ed1ffb93-aa9c-4de2-b8ad-5f2843e0695a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %%
# @title 90
import pdf2image
from PIL import Image
import pytesseract
from google.colab import files
import os

def pdf_to_img(pdf_file):
    # return pdf2image.convert_from_path(pdf_file)
    return pdf_file

def ocr_core(file):
    text = pytesseract.image_to_string(file)
    return text

def extract_isbn(text):
    start = text.find("ISBN")
    end = text.find("\n", start)
    isbn = text[start:end].replace("ISBN", "").strip()
    return isbn

def extract_penulis(text):
    start = text.find("Penulis")
    end = text.find("\n", start)
    penulis = text[start:end].replace("Penulis", "").strip()
    return penulis

def print_info(pdf_file):
    text_data_buku = ""
    text_data_buku += ocr_core(pdf_file)

    isbn = extract_isbn(text_data_buku)
    penulis = extract_penulis(text_data_buku)

    print("ISBN:", isbn)
    print("Penulis:", penulis)

def select_pdf_file():
    uploaded = files.upload()
    for file_name in uploaded.keys():
        return file_name

def collect_ground_truth_data():
    ground_truth_data = {}

    print("Please upload PDF files. Type 'done' when finished.")
    while True:
        pdf_file = select_pdf_file()
        if pdf_file:
            ground_truth_data[pdf_file] = pdf_file
            print("File {} uploaded.".format(pdf_file))
        else:
            print("No PDF file uploaded.")

        stop_collecting = input("Do you want to stop collecting data? (yes/no): ").lower()
        if stop_collecting == "yes":
            break

    return ground_truth_data

if __name__ == "__main__":
    ground_truth_data = collect_ground_truth_data()

    for pdf_file in ground_truth_data.values():
        print("Processing PDF:", pdf_file)
        print_info(pdf_file)
# Out:
# Please upload PDF files. Type 'done' when finished.
#      <input type="file" id="files-e50beb7b-106d-4434-b3f0-6f6503097e2a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e50beb7b-106d-4434-b3f0-6f6503097e2a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %%
# @title 180 image
import pdf2image
from PIL import Image
import pytesseract
from google.colab import files
import os

def pdf_to_img(pdf_file):
    # return pdf2image.convert_from_path(pdf_file)
    return pdf_file

def ocr_core(file):
    text = pytesseract.image_to_string(file)
    return text

def extract_isbn(text):
    start = text.find("ISBN")
    end = text.find("\n", start)
    isbn = text[start:end].replace("ISBN", "").strip()
    return isbn

def extract_penulis(text):
    start = text.find("Penulis")
    end = text.find("\n", start)
    penulis = text[start:end].replace("Penulis", "").strip()
    return penulis

def print_info(pdf_file):
    text_data_buku = ""
    text_data_buku += ocr_core(pdf_file)

    isbn = extract_isbn(text_data_buku)
    penulis = extract_penulis(text_data_buku)

    print("ISBN:", isbn)
    print("Penulis:", penulis)

def select_pdf_file():
    uploaded = files.upload()
    for file_name in uploaded.keys():
        return file_name

def collect_ground_truth_data():
    ground_truth_data = {}

    print("Please upload PDF files. Type 'done' when finished.")
    while True:
        pdf_file = select_pdf_file()
        if pdf_file:
            ground_truth_data[pdf_file] = pdf_file
            print("File {} uploaded.".format(pdf_file))
        else:
            print("No PDF file uploaded.")

        stop_collecting = input("Do you want to stop collecting data? (yes/no): ").lower()
        if stop_collecting == "yes":
            break

    return ground_truth_data

if __name__ == "__main__":
    ground_truth_data = collect_ground_truth_data()

    for pdf_file in ground_truth_data.values():
        print("Processing PDF:", pdf_file)
        print_info(pdf_file)
# Out:
# Please upload PDF files. Type 'done' when finished.
#      <input type="file" id="files-2bf7bb16-8ba1-42a2-b03a-0afe6d3ea2c7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2bf7bb16-8ba1-42a2-b03a-0afe6d3ea2c7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %%
# @title 270 image
import pdf2image
from PIL import Image
import pytesseract
from google.colab import files
import os

def pdf_to_img(pdf_file):
    # return pdf2image.convert_from_path(pdf_file)
    return pdf_file

def ocr_core(file):
    text = pytesseract.image_to_string(file)
    return text

def extract_isbn(text):
    start = text.find("ISBN")
    end = text.find("\n", start)
    isbn = text[start:end].replace("ISBN", "").strip()
    return isbn

def extract_penulis(text):
    start = text.find("Penulis")
    end = text.find("\n", start)
    penulis = text[start:end].replace("Penulis", "").strip()
    return penulis

def print_info(pdf_file):
    text_data_buku = ""
    text_data_buku += ocr_core(pdf_file)

    isbn = extract_isbn(text_data_buku)
    penulis = extract_penulis(text_data_buku)

    print("ISBN:", isbn)
    print("Penulis:", penulis)

def select_pdf_file():
    uploaded = files.upload()
    for file_name in uploaded.keys():
        return file_name

def collect_ground_truth_data():
    ground_truth_data = {}

    print("Please upload PDF files. Type 'done' when finished.")
    while True:
        pdf_file = select_pdf_file()
        if pdf_file:
            ground_truth_data[pdf_file] = pdf_file
            print("File {} uploaded.".format(pdf_file))
        else:
            print("No PDF file uploaded.")

        stop_collecting = input("Do you want to stop collecting data? (yes/no): ").lower()
        if stop_collecting == "yes":
            break

    return ground_truth_data

if __name__ == "__main__":
    ground_truth_data = collect_ground_truth_data()

    for pdf_file in ground_truth_data.values():
        print("Processing PDF:", pdf_file)
        print_info(pdf_file)
# Out:
# Please upload PDF files. Type 'done' when finished.
#      <input type="file" id="files-763d4129-ae09-4531-8572-dcca19693561" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-763d4129-ae09-4531-8572-dcca19693561">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %% [markdown]
# # gh

# %% [markdown]
# ---

# %%
import requests
from bs4 import BeautifulSoup

def search_book_by_isbn(isbn):
    url = "https://isbn.perpusnas.go.id/Account/SearchBuku"

    data = {
        "searchTxt": isbn,
        "searchCat": "ISBN"
    }

    response = requests.post(url, data=data)

    if response.status_code == 200:
        soup = BeautifulSoup(response.content, "html.parser")
        # Process the search results here
        # For example, you can extract book title, author, publisher, etc.
    else:
        print("Error: Failed to fetch search results.")

if __name__ == "__main__":
    isbn_number = input("Enter the ISBN number: ")
    search_book_by_isbn(isbn_number)
# Out:
# Enter the ISBN number: 978-602-06-3287-2

# %%
from PIL import Image
import pytesseract
from google.colab import files
import os

def ocr_core(image):
    text = pytesseract.image_to_string(image)
    return text

def extract_isbn(text):
    start = text.find("ISBN")
    end = text.find("\n", start)
    isbn = text[start:end].replace("ISBN", "").strip()
    return isbn

def extract_penulis(text):
    start = text.find("Penulis")
    end = text.find("\n", start)
    penulis = text[start:end].replace("Penulis", "").strip()
    return penulis

def collect_ground_truth_data():
    ground_truth_data = {}

    print("Please upload image files. Type 'done' when finished.")
    while True:
        file_name = select_image_file()
        if file_name:
            with open(file_name, "rb") as file:
                text_data = file.read()
            ground_truth_data[file_name] = text_data
            print("File {} uploaded and text data saved.".format(file_name))
        else:
            print("No file uploaded.")

        stop_collecting = input("Do you want to stop collecting data? (yes/no): ").lower()
        if stop_collecting == "yes":
            break

    return ground_truth_data

def calculate_word_error_rate(actual_text, ocr_text):
    actual_words = actual_text.lower().split()
    ocr_words = ocr_text.lower().split()

    total_words = len(actual_words)
    word_errors = sum(1 for word in ocr_words if word not in actual_words)

    if total_words == 0:
        word_error_rate = 0
    else:
        word_error_rate = word_errors / total_words

    return word_error_rate

def calculate_recall_precision(ground_truth_data, ocr_data):
    total_ground_truth_words = 0
    total_correctly_detected_words = 0
    total_detected_words = 0

    for file_name, ground_truth_text in ground_truth_data.items():
        ocr_text = ocr_data.get(file_name, "")

        ground_truth_words = set(ground_truth_text.lower().split())
        ocr_words = set(ocr_text.lower().split())

        correctly_detected_words = ground_truth_words.intersection(ocr_words)
        total_correctly_detected_words += len(correctly_detected_words)

        total_ground_truth_words += len(ground_truth_words)
        total_detected_words += len(ocr_words)

    if total_ground_truth_words == 0:
        # Handle the case when ground_truth_data is empty to avoid division by zero
        recall = 0
    else:
        recall = total_correctly_detected_words / total_ground_truth_words

    if total_detected_words == 0:
        # Handle the case when there are no detected words to avoid division by zero
        precision = 0
    else:
        precision = total_correctly_detected_words / total_detected_words

    return recall, precision

if __name__ == "__main__":
    ground_truth_data = collect_ground_truth_data()

    ocr_results = {}
    for image_file, actual_text in ground_truth_data.items():
        print("Processing image:", image_file)

        image = Image.open(image_file)

        text_data_buku = ocr_core(image)
        isbn = extract_isbn(text_data_buku)
        penulis = extract_penulis(text_data_buku)

        print("ISBN:", isbn)
        print("Penulis:", penulis)

        ocr_results[image_file] = text_data_buku

    recall, precision = calculate_recall_precision(ground_truth_data, ocr_results)
    print("Recall: {:.2f}".format(recall))
    print("Precision: {:.2f}".format(precision))
# Out:
# Please upload image files. Type 'done' when finished.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-8ee22d27e4b8> in <cell line: 87>()
#      86
#      87 if __name__ == "__main__":
# ---> 88     ground_truth_data = collect_ground_truth_data()
#      89
#      90     ocr_results = {}
#
# <ipython-input-8-8ee22d27e4b8> in collect_ground_truth_data()
#      25     print("Please upload image files. Type 'done' when finished.")
#      26     while True:
# ---> 27         file_name = select_image_file()
#      28         if file_name:
#      29             with open(file_name, "rb") as file:
#
# NameError: name 'select_image_file' is not defined
